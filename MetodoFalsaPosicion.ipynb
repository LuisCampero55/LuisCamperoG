# %%
# Método de la Bisección - Ejercicio 1
import matplotlib.pyplot as plt
lxr = list()

def biseccion(xl = 6, xu = 7):
  print("Método de la Bisección")
  print("Siendo Xl = 6, Xu = 7")
  fxu=((-0.5 * (xu**2)) + (2.5 * xu) + 4.5)
  fxl = ((-0.5 * (xl**2)) + (2.5 * xl) + 4.5)
  if (fxu * fxl < 0):
     xr = (xl + xu) / 2
     fxr = ((-0.5 * (xr**2)) + (2.5 * xr) + 4.5)
     print("El valor de Xr es: " + str(xr))
     lxr.append(xr)
     num = 1
     while num < 4:
         num = num + 1
         if (fxu * fxr < 0):             
             xl = xr
             fxu=((-0.5 * (xu**2)) + (2.5 * xu) + 4.5)
             fxl = ((-0.5 * (xl**2)) + (2.5 * xl) + 4.5)
             xr = (xl + xu) / 2
             fxr = ((-0.5 * (xr**2)) + (2.5 * xr) + 4.5)             
             print("El valor de Xr es: " + str(xr))
             lxr.append(xr)
         if (fxl * fxr < 0):
             xu = xr
             fxu=((-0.5 * (xu**2)) + (2.5 * xu) + 4.5)
             fxl = ((-0.5 * (xl**2)) + (2.5 * xl) + 4.5)
             xr = (xl + xu) / 2
             fxr = ((-0.5 * (xr**2)) + (2.5 * xr) + 4.5)
             print("El valor de Xr es: " + str(xr))
             lxr.append(xr)
         if (fxu * fxr > 0 and fxl * fxr > 0):
             print("No tiene raiz")
  else:
     print("No tiene raiz")
biseccion()
plt.plot(lxr)  
plt.show()
# Out:
# Método de la Bisección
# Siendo Xl = 6, Xu = 7
# El valor de Xr es: 6.5
# El valor de Xr es: 6.25
# El valor de Xr es: 6.375
# El valor de Xr es: 6.4375
# El valor de Xr es: 6.40625

# %%
#Metodo Falsa Posicion - Ejercicio 1
import matplotlib.pyplot as plt

def falsaPosicion(xu = 7, xl = 6):
    print("Método de Falsa Posicion")
    print("Siendo Xl = 6, Xu = 7")
    fxu=((-0.5 * (xu**2)) + (2.5 * xu) + 4.5)
    fxl = ((-0.5 * (xl**2)) + (2.5 * xl) + 4.5)
    lxr = list()
    if(fxu * fxl < 0):
        xr = (xu - ((fxu * (xl - xu) / (fxl - fxu))))
        fxr =((-0.5 * (xr**2)) + (2.5 * xr) + 4.5)
        lxr.append(xr)
        print("El valor de Xr es: " + str(xr))
        er = 1
        while er > (10**-5):
            if(fxu * fxr < 0):
                xl = xr
                fxl =((-0.5 * (xl**2)) + (2.5 * xl) + 4.5)
                fxu =((-0.5 * (xu**2)) + (2.5 * xu) + 4.5)
                xr = (xu - ((fxu * (xl - xu) / (fxl - fxu))))
                fxr =((-0.5 * (xr**2)) + (2.5 * xr) + 4.5)
                er=(xr-xl)/xr
                lxr.append(xr)
                print("El valor de Xr es: " + str(xr))
            if (fxl * fxr < 0):
                xu=xr
                fxl = ((-0.5 * (xl**2)) + (2.5 * xl) + 4.5)
                fxu = ((-0.5 * (xu**2)) + (2.5 * xu) + 4.5)
                xr = (xu - ((fxu * (xl - xu) / (fxl - fxu))))
                fxr = ((-0.5 * (xr**2)) + (2.5 * xr) + 4.5)
                er = (xr - xl) / xr
                lxr.append(xr)
                print("El valor de Xr es: " + str(xr))
            if (fxu * fxr > 0 and fxl * fxr > 0):
                print("No tiene raiz, fin del programa")
        plt.plot(lxr)
        plt.show
    else:
        print("No tiene raiz, fin del programa")
falsaPosicion()
# Out:
# Método de Falsa Posicion
# Siendo Xl = 6, Xu = 7
# El valor de Xr es: 6.375
# El valor de Xr es: 6.402985074626866
# El valor de Xr es: 6.404973357015986
# El valor de Xr es: 6.4051141166525785
# El valor de Xr es: 6.405124079149171

# %%
# Método de Bisección - Ejercicio 2
import matplotlib.pyplot as plt
lxr = list()

def biseccion(xl = 1, xu = 0):
  print("Método de Bisección")
  print("Siendo Xl = 1, Xu = 0")
  fxu=((5 * (xu**3)) + (5 * (xu**2)) + (6 * xu) - 2)
  fxl = ((5 * (xl**3)) + (5 * (xl**2)) + (6 * xl) - 2)
  if (fxu * fxl < 0):
     xr = (xl + xu) / 2
     fxr = ((5 * (xu*3)) + (5 * xu*2) + (6 * xu) - 2)
     print("El valor de Xr es: " + str(xr))
     lxr.append(xr)
     num = 1
     while num < 4:
         num = num + 1
         if (fxu * fxr < 0):             
             xl = xr
             fxu=((5 * (xu*3)) + (5 * xu*2) + (6 * xu) - 2)
             fxl = ((5 * (xl*3)) + (5 * xl*2) + (6 * xl) - 2)
             xr = (xl + xu) / 2
             fxr = ((5 * (xu*3)) + (5 * xu*2) + (6 * xu) - 2)             
             print("El valor de Xr es: " + str(xr))
             lxr.append(xr)
         if (fxl * fxr < 0):
             xu = xr
             fxu=((5 * (xu*3)) + (5 * xu*2) + (6 * xu) - 2)
             fxl = ((5 * (xl*3)) + (5 * xl*2) + (6 * xl) - 2)
             xr = (xl + xu) / 2
             fxr = ((5 * (xu*3)) + (5 * xu*2) + (6 * xu) - 2)
             print("El valor de Xr es: " + str(xr))
             lxr.append(xr)
         if (fxu * fxr > 0 and fxl * fxr > 0):
             print("No tiene raiz")
  else:
     print("No tiene raiz")
biseccion()
plt.plot(lxr)  
plt.show()
# Out:
# Método de Bisección
# Siendo Xl = 1, Xu = 0
# El valor de Xr es: 0.5
# El valor de Xr es: 0.75
# No tiene raiz
# No tiene raiz
# No tiene raiz

# %%
# Método de la Bisección - Ejercicio 3
import matplotlib.pyplot as plt
import math

lxr = list()
def biseccion(xl = .5, xu = 2):
  print("Método de la Bisección")
  print("Siendo Xl = .5, Xu = 2")
  fxu = (math.log(xu**2) - .7)
  fxl = (math.log(xl**2) - .7)
  if (fxu * fxl < 0):
     xr = (xl + xu) / 2
     fxr = (math.log(xr**2) - .7)
     print("El valor de Xr es: " + str(xr))
     lxr.append(xr)
     num = 1
     while num < 2:
         num = num + 1
         if (fxu * fxr < 0):
             xl = xr
             fxu = (math.log(xu**2) - .7)
             fxl = (math.log(xl**2) - .7)
             xr = (xl + xu) / 2
             fxr = (math.log(xr**2) - .7)
             print("El valor de Xr es: " + str(xr))
             lxr.append(xr)
         if (fxl * fxr < 0):
             xu = xr
             fxu = (math.log(xu**2) - .7)
             fxl = (math.log(xl**2) - .7)
             xr = (xl + xu) / 2
             fxr = (math.log(xr**2) - .7)
             print("El valor de Xr es: " + str(xr))
             lxr.append(xr)
         if (fxu * fxr > 0 and fxl * fxr > 0):
             print("No tiene raiz")
  else:
     print("No tiene raiz")
biseccion()
plt.plot(lxr)  
plt.show()
# Out:
# Método de la Bisección
# Siendo Xl = .5, Xu = 2
# El valor de Xr es: 1.25
# El valor de Xr es: 1.625
# El valor de Xr es: 1.4375

# %%
#Método Bisección - Ejercicio 4
import matplotlib.pyplot as plt
import math

lxr = list()
def biseccion(xl = 1, xu = 3):
    print("Metodo de la Biseccion")
    print("Siendo Xl = 1, Xu = 3")
    fxl = (math.sqrt((xl**7)))
    fxu = (math.sqrt((xu**7)))
    if (fxu * fxl < 0):
        xr = (xl + xu) / 2
        fxr = (math.sqrt((xr**7)))
        lxr.append(xr)
        print("\n El valor de Xu es: " + str(xu))
        print("El valor de Xl es: " + str(xl))
        print("El valor de Xr es: " + str(xr))
        print("El valor de F(Xu) es: " + str(fxu))
        print("El valor de F(Xl) es: " + str(fxl))
        print("El valor de F(Xr) es: " + str(fxr))
        er = 1
        while er > (10**-5):
            if(fxu * fxr < 0):
                xl = xr
                fxl = (math.sqrt((xl**7)))
                fxu = (math.sqrt((xu**7)))
                xr = (xl + xu) / 2
                fxr = (math.sqrt((xr**7)))
                er = (xr - xl) / xr
                lxr.append(xr)
                print("\n El valor de Xu es: " + str(xu))
                print("El valor de Xl es: " + str(xl))
                print("El valor de Xr es: " + str(xr))
                print("El valor de F(Xu) es: " + str(fxu))
                print("El valor de F(Xl) es: " + str(fxl))
                print("El valor de F(Xr) es: " + str(fxr))
            if (fxl * fxr < 0):
                xu = xr
                fxl = (math.sqrt((xl**7)))
                fxu = (math.sqrt((xu**7)))
                xr = (xl + xu) / 2
                fxr = (math.sqrt((xr**7)))
                er = (xr - xl) / xr
                lxr.append(xr)
                print("\n El valor de Xu es: " + str(xu))
                print("El valor de Xl es: " + str(xl))
                print("El valor de Xr es: " + str(xr))
                print("El valor de F(Xu) es: " + str(fxu))
                print("El valor de F(Xl) es: " + str(fxl))
                print("El valor de F(Xr) es: " + str(fxr))
            if (fxu*fxr>0 and fxl*fxr>0):
                print("No tiene raiz, fin del programa")
        plt.plot(lxr)
        plt.show
    else:
        print("No tiene raiz, fin del programa")
biseccion()
# Out:
# Metodo de la Biseccion
# Siendo Xl = 1, Xu = 3
# No tiene raiz, fin del programa

# %%
import matplotlib.pyplot as plt
import math

lxr = list()
def falsaPosicion(xu = 3, xl = 1):
    print("Metodo de la Falsa posicion")
    print("Siendo Xl = 1, Xu = 3")
    fxl=(math.sqrt((xl**7)))
    fxu=(math.sqrt((xu**7)))
    if(fxu*fxl<0):
        xr=(xu-((fxu*(xl-xu)/(fxl-fxu))))
        fxr = (math.sqrt((xr**7)))
        lxr.append(xr)
        c=0
        print("\n El valor de Xu es: " + str(xu))
        print("El valor de Xl es: " + str(xl))
        print("El valor de Xr es: " + str(xr))
        print("El valor de F(Xu) es: " + str(fxu))
        print("El valor de F(Xl) es: " + str(fxl))
        print("El valor de F(Xr) es: " + str(fxr))
        er = 1
        while er > (10**-5):
            if(fxu*fxr<0):
                xl=xr
                fxl = (math.sqrt((xl**7)))
                fxu = (math.sqrt((xu**7)))
                xr = (xu-((fxu*(xl-xu)/(fxl-fxu))))
                fxr = (math.sqrt((xr**7)))
                er=(xr-xl)/xr
                lxr.append(xr)
                print("\n El valor de Xu es: " + str(xu))
                print("El valor de Xl es: " + str(xl))
                print("El valor de Xr es: " + str(xr))
                print("El valor de F(Xu) es: " + str(fxu))
                print("El valor de F(Xl) es: " + str(fxl))
                print("El valor de F(Xr) es: " + str(fxr))
            if (fxl * fxr < 0):
                xu=xr
                fxl =(math.sqrt((xl**7)))
                fxu =(math.sqrt((xu**7)))
                xr = (xu-((fxu*(xl-xu)/(fxl-fxu))))
                fxr =(math.sqrt((xr**7)))
                er = (xr - xl) / xr
                lxr.append(xr)
                print("\n El valor de Xu es: " + str(xu))
                print("El valor de Xl es: " + str(xl))
                print("El valor de Xr es: " + str(xr))
                print("El valor de F(Xu) es: " + str(fxu))
                print("El valor de F(Xl) es: " + str(fxl))
                print("El valor de F(Xr) es: " + str(fxr))
            if (fxu*fxr>0 and fxl*fxr>0):
                print("No tiene raiz, fin del programa")
        plt.plot(lxr)
        plt.show
    else:
        print("No tiene raiz, fin del programa")
falsaPosicion()
# Out:
# Metodo de la Falsa posicion
# Siendo Xl = 1, Xu = 3
# No tiene raiz, fin del programa
