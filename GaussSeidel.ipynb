# %%
import matplotlib.pyplot as plt
import math

def e1(y):
    return (.25 * (1 + y))
def e2(x, z):
  return ((.25) * (1 + x + z))
def e3(x, w):
    return ((.25) * (1 + x + w))
def e4(z):
    return (.25 * (1 + z))

#Nuevo método
def GaussSeidel():
  print("Gauss Seidel")
  Mfg1()

def Mfg1():
  xDat=[]
  xDat.append(0)
  yDat=[]
  yDat.append(0)
  zDat=[]
  zDat.append(0)
  wDat=[]
  wDat.append(0)
  cont = 0
  x = 0
  y = 0
  z = 0
  w = 0
  #it = True
  while(cont < 11):
    xd = e1(y)
    xDat.append(xd)
    x = xd
    yd = e2(x , z)
    yDat.append(yd)
    y = yd
    zd = e3(x, w)
    zDat.append(zd)
    z = zd
    wd = e4(z)
    wDat.append(wd)
    w = wd
    cont += 1
  plt.plot(xDat, label = "x_Dato")
  plt.plot(yDat, label = "y_Dato")
  plt.plot(zDat, label = "z_Dato")
  plt.plot(wDat, label = "w_Dato")
  plt.legend()
  plt.show()
  print("Iteraciones: \n")
  print("x : " + str(xDat))
  print("y : " + str(yDat))
  print("z : " + str(zDat))
  print("w : " + str(wDat))

GaussSeidel()
# Out:
# Gauss Seidel
# Iteraciones:
#
# x : [0, 0.25, 0.328125, 0.3525390625, 0.36041259765625, 0.3616828918457031, 0.36193394660949707, 0.36198021471500397, 0.36198894027620554, 0.36199057317571715, 0.3619908795408264, 0.36199093697200624]
# y : [0, 0.3125, 0.41015625, 0.441650390625, 0.4467315673828125, 0.4477357864379883, 0.44792085886001587, 0.44795576110482216, 0.4479622927028686, 0.4479635181633057, 0.44796374788802495, 0.44796379096447936]
# z : [0, 0.3125, 0.4140625, 0.426513671875, 0.42926025390625, 0.4297494888305664, 0.42984282970428467, 0.4298602305352688, 0.4298634994775057, 0.4298641120112734, 0.4298642268859112, 0.429864248423371]
# w : [0, 0.328125, 0.353515625, 0.35662841796875, 0.3573150634765625, 0.3574373722076416, 0.35746070742607117, 0.3574650576338172, 0.3574658748693764, 0.35746602800281835, 0.3574660567214778, 0.35746606210584275]
