# %%
# Método de la Bisección
# Utilizando la función presentada en clase
import matplotlib.pyplot as plt
lxr = list()
def biseccion(xl = 1, xu=2):
  print("Método de la Bisección")
  print("Siendo Xl = 1, Xu = 2")
  fxl = (xl ** 3) + (4 * (xl ** 2) - 10)
  fxu = (xu ** 3) + (4 * (xu ** 2) - 10)
  if (fxu * fxl < 0):
     xr = (xl + xu) / 2
     fxr = (xr ** 3) + (4 * (xr ** 2) - 10)
     print(xr)
     lxr.append(xr)
     num = 1
     while num > 0.001:
         if (fxu * fxr < 0):
             xl = xr
             fxl = (xl ** 3) + (4 * (xl ** 2) - 10)
             fxu = (xu ** 3) + (4 * (xu ** 2) - 10)
             xr = (xl + xu) / 2
             fxr = (xr ** 3) + (4 * (xr ** 2) - 10)
             num = (xr - xl) / xr
             print(xr)
             lxr.append(xr)
         if (fxl * fxr < 0):
             xu = xr
             fxl = (xl ** 3) + (4 * (xl ** 2) - 10)
             fxu = (xu ** 3) + (4 * (xu ** 2) - 10)
             xr = (xl + xu) / 2
             fxr = (xr ** 3) + (4 * (xr ** 2) - 10)
             er = (xr - xl) / xr
             print(xr)
             lxr.append(xr)
         if (fxu * fxr > 0 and fxl * fxr > 0):
             print("No tiene raiz")
  else:
     print("No tiene raiz")
biseccion()
plt.plot(lxr)  
plt.show()
# Out:
# Método de la Bisección
# Siendo Xl = 1, Xu = 2
# 1.5
# 1.25
# 1.375
# 1.3125
# 1.34375
# 1.359375
# 1.3671875
# 1.36328125
# 1.365234375
# 1.3642578125
# 1.36474609375
