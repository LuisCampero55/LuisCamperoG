# %%
# Punto Fijo

import matplotlib.pyplot as plt
import math

def puntoFijo():
  print("Eliga su ecuación a validar")
  print("1) 2x^2-5")
  print("2) 5/2x-1")
  print("3) √x+5/2")
  opc = int(input("Opción: "))
  print("Ingrese su valor inicial")
  vi = int(input("Valor inicial: "))
  print("Ingrese su criterio de paro: ")
  cp = float(input("Criterio de paro: "))
  if (opc == 1):
    fg1(vi, cp)
  if (opc == 2):
    fg2(vi, cp)
  if (opc == 3):
    fg3(vi, cp)

puntoFijo()

#Ecuación 1
def g1(x):
  return ((2*(x**2))-5)

def fg1(vi, cp=0.0001):
  x_vec=[]
  x_vec.append(xinicial)
  contador = 0
  error_vec=[]
  error_vec.append(1)
  criterio_paro = criterio
  iteraciones = True
  while(error_vec[contador] > criterio_paro):
    x_temp = g1(x_vec[contador])
    x_vec.append(x_temp)
    print(x_vec)
    e_temp = abs(x_vec[contador+1]-x_vec[contador])
    error_vec.append(e_temp)
    contador += 1
    if (x_vec[contador]>=2000):
      iteraciones = False
      break
  print(iteraciones)
  print("Grafica")
  plt.plot(x_vec)
  plt.show()
  print("Grafica error")
  plt.plot(error_vec)
  plt.show() 

#Ecuación 2

def g2(x):
    return 5/(2*x-1)

def fg2(xinicial, criterio=0.0001):
  x_vec=[]
  x_vec.append(xinicial)
  contador = 0
  error_vec=[]
  error_vec.append(1)
  criterio_paro = criterio
  iteraciones = True
  while(error_vec[contador] > criterio_paro):
    x_temp = g2(x_vec[contador])
    x_vec.append(x_temp)
    e_temp = abs(x_vec[contador+1]-x_vec[contador])
    error_vec.append(e_temp)
    contador += 1
    if (x_vec[contador]>=2000):
      iteraciones = False
      break
  print(iteraciones)
  print("Raiz = "+str(x_vec[contador]))
  print("Grafica")
  plt.plot(x_vec)
  plt.show()
  print("Grafica error")
  plt.plot(error_vec)
  plt.show()

#Ecuación 3

def g3(x):
  return math.sqrt((x+5)/2)

def fg3(xinicial, criterio=0.0001):
  x_vec=[]
  x_vec.append(xinicial)
  contador = 0
  error_vec=[]
  error_vec.append(1)
  criterio_paro = criterio
  iteraciones = True
  while(error_vec[contador] > criterio_paro):
    x_temp = g3(x_vec[contador])
    x_vec.append(x_temp)
    e_temp = abs(x_vec[contador+1]-x_vec[contador])
    error_vec.append(e_temp)
    contador += 1
    if (x_vec[contador]>=2000):
      iteraciones = False
      break
  print(iteraciones)
  print("Raiz = "+str(x_vec[contador]))
  print("Grafica")
  plt.plot(x_vec)
  plt.show()
  print("Grafica error")
  plt.plot(error_vec)
  plt.show()
